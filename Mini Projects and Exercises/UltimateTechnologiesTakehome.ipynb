# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Part 1 EDA

# %%
with open('logins.json', 'r') as f:
    data = json.load(f)
logins = pd.DataFrame(data)

# %%
logins['index'] = logins.index

logins['login_time'] = pd.to_datetime(logins['login_time'])
logins = logins.set_index('login_time')

# %%
logins = logins.groupby(logins.index.floor('15T').time).count().sort_values(by='index', ascending=False)

# %%
logins.reset_index(level=0, inplace=True)

display(logins)
# Out:
#      level_0  index
# 0   22:30:00   1684
# 1   01:30:00   1673
# 2   22:15:00   1652
# 3   22:45:00   1637
# 4   22:00:00   1634
# ..       ...    ...
# 91  06:45:00    214
# 92  07:30:00    192
# 93  08:00:00    191
# 94  08:15:00    179
# 95  07:45:00    175
#
# [96 rows x 2 columns]

# %%
logins = logins.rename(columns={'level_0': 'time', 'index': 'countofusers'})

loginstop30 = logins.head(30)

loginstop30['time'] = loginstop30['time'].astype('string')
loginstop30 = loginstop30.set_index('time')
# Out:
# <ipython-input-6-aa246d490c4b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loginstop30['time'] = loginstop30['time'].astype('string')

# %%
plt.figure(figsize=(9, 3))
plt.plot(loginstop30)
plt.xticks(rotation='vertical')
plt.title('Users per 15 Min (Highest)')
plt.xlabel('time')
plt.ylabel('countofusers')
# Out:
# Text(0, 0.5, 'countofusers')

# %%
loginsbottom30 = logins.tail(30)

loginsbottom30['time'] = loginsbottom30['time'].astype('string')
loginsbottom30 = loginsbottom30.set_index('time')
# Out:
# <ipython-input-8-55e7328b53b1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loginsbottom30['time'] = loginsbottom30['time'].astype('string')

# %%
plt.figure(figsize=(9, 3))
plt.plot(loginsbottom30)
plt.xticks(rotation='vertical')
plt.title('Users per 15 Min (Lowest)')
plt.xlabel('time')
plt.ylabel('countofusers')
# Out:
# Text(0, 0.5, 'countofusers')

# %%
logins['time'] = logins['time'].astype('string')
logins = logins.set_index('time')

# %%
plt.figure(figsize=(25, 3))
plt.plot(logins)
plt.xticks(rotation='vertical')
plt.title('Users per 15 Min (All)')
plt.xlabel('time')
plt.ylabel('countofusers')
# Out:
# Text(0, 0.5, 'countofusers')

# %%
hours = pd.DataFrame(data)

# %%
hours['index'] = hours.index

hours['login_time'] = pd.to_datetime(hours['login_time'])
hours = hours.set_index('login_time')

# %%
hours = hours.groupby(hours.index.floor('1h').time).count().sort_values(by='index', ascending=False)

# %%
display(hours)
# Out:
#           index
# 22:00:00   6607
# 01:00:00   6317
# 23:00:00   6058
# 00:00:00   5993
# 02:00:00   5800
# 11:00:00   5799
# 21:00:00   5623
# 04:00:00   5034
# 12:00:00   4964
# 03:00:00   4831
# 20:00:00   4103
# 13:00:00   3611
# 14:00:00   3426
# 19:00:00   3235
# 10:00:00   3064
# 15:00:00   3038
# 18:00:00   2980
# 05:00:00   2945
# 16:00:00   2832
# 17:00:00   2584
# 09:00:00   1527
# 06:00:00   1138
# 08:00:00    818
# 07:00:00    815

# %%
hours.reset_index(level=0, inplace=True)

display(hours)
# Out:
#      level_0  index
# 0   22:00:00   6607
# 1   01:00:00   6317
# 2   23:00:00   6058
# 3   00:00:00   5993
# 4   02:00:00   5800
# 5   11:00:00   5799
# 6   21:00:00   5623
# 7   04:00:00   5034
# 8   12:00:00   4964
# 9   03:00:00   4831
# 10  20:00:00   4103
# 11  13:00:00   3611
# 12  14:00:00   3426
# 13  19:00:00   3235
# 14  10:00:00   3064
# 15  15:00:00   3038
# 16  18:00:00   2980
# 17  05:00:00   2945
# 18  16:00:00   2832
# 19  17:00:00   2584
# 20  09:00:00   1527
# 21  06:00:00   1138
# 22  08:00:00    818
# 23  07:00:00    815

# %%
hours = hours.rename(columns={'level_0': 'HourofDay', 'index': 'countofusers'})

display(hours)
# Out:
#    HourofDay  countofusers
# 0   22:00:00          6607
# 1   01:00:00          6317
# 2   23:00:00          6058
# 3   00:00:00          5993
# 4   02:00:00          5800
# 5   11:00:00          5799
# 6   21:00:00          5623
# 7   04:00:00          5034
# 8   12:00:00          4964
# 9   03:00:00          4831
# 10  20:00:00          4103
# 11  13:00:00          3611
# 12  14:00:00          3426
# 13  19:00:00          3235
# 14  10:00:00          3064
# 15  15:00:00          3038
# 16  18:00:00          2980
# 17  05:00:00          2945
# 18  16:00:00          2832
# 19  17:00:00          2584
# 20  09:00:00          1527
# 21  06:00:00          1138
# 22  08:00:00           818
# 23  07:00:00           815

# %%
hours['HourofDay'] = hours['HourofDay'].astype('string')
hours = hours.set_index('HourofDay')

# %%
plt.figure(figsize=(9, 3))
plt.plot(hours)
plt.xticks(rotation='vertical')
plt.title('users per hour of day')
plt.xlabel('hours')
plt.ylabel('countofusers')
# Out:
# Text(0, 0.5, 'countofusers')

# %% [markdown]
# #### Part 2 - Experiments and Metrics Design

# %%
### Key Measure

# %%
### Ratio of Users who now drive in both cities as compared to exclusively one city in the past
### Count of Users in each city
### Revenue
### Time to passengers hopefully to decrease

# %%
### To experiment we would roll out the feature to two random samples from the pools of drivers that drive exclusively in each city.

### 1st random sample would be Gotham drivers
### 2nd random sample would be Metropolis drivers

### We will roll out the test for a minimum of 2 weeks , and use a p-test to verify any possible signficant results found from the test.

### If any of the key metrics improve from the ones recommended in part 1, we will study how it could affect our bottom line, and all other facets of user experience, and ultimately decide whether or not to roll-out the feature, and how to roll it out.

# %% [markdown]
# ### Part 3 - EDA + Predictive Modeling

# %% [markdown]
# ### Part 3a - EDA

# %%
with open('ultimate_data_challenge.json', 'r') as f:
    data = json.load(f)
challenge = pd.DataFrame(data)

# %%
display(challenge)
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 1             Astapor                       0  2014-01-29
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# ...               ...                     ...         ...
# 49995  King's Landing                       0  2014-01-25
# 49996         Astapor                       1  2014-01-24
# 49997      Winterfell                       0  2014-01-31
# 49998         Astapor                       2  2014-01-14
# 49999         Astapor                       0  2014-01-18
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 1                       5.0       1.00     2014-05-05  Android        0.0
# ...

# %%
challenge.dtypes
# Out:
# city                       object
# trips_in_first_30_days      int64
# signup_date                object
# avg_rating_of_driver      float64
# avg_surge                 float64
# last_trip_date             object
# phone                      object
# surge_pct                 float64
# ultimate_black_user          bool
# weekday_pct               float64
# avg_dist                  float64
# avg_rating_by_driver      float64
# dtype: object

# %%
challenge['signup_date'] = pd.to_datetime(challenge['signup_date'])
challenge['last_trip_date'] = pd.to_datetime(challenge['last_trip_date'])

# %%
challenge.isnull().values.any()
# Out:
# True

# %%
challenge[challenge.isnull().any(axis=1)]
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 6         Astapor                       1  2014-01-24                   NaN
# 9      Winterfell                       1  2014-01-03                   NaN
# 12     Winterfell                       1  2014-01-15                   NaN
# 14        Astapor                       1  2014-01-27                   NaN
# 15     Winterfell                       1  2014-01-15                   NaN
# ...           ...                     ...         ...                   ...
# 49984  Winterfell                       1  2014-01-26                   NaN
# 49985     Astapor                       1  2014-01-26                   NaN
# 49989  Winterfell                       1  2014-01-24                   NaN
# 49996     Astapor                       1  2014-01-24                   NaN
# 49999     Astapor                       0  2014-01-18                   NaN
#
# ...

# %%
challenge[challenge['trips_in_first_30_days'] >= 2]
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 0      King's Landing                       4  2014-01-25
# 2             Astapor                       3  2014-01-06
# 3      King's Landing                       9  2014-01-10
# 4          Winterfell                      14  2014-01-27
# 5          Winterfell                       2  2014-01-09
# ...               ...                     ...         ...
# 49975      Winterfell                      11  2014-01-11
# 49977         Astapor                       4  2014-01-06
# 49987      Winterfell                       3  2014-01-27
# 49993         Astapor                       3  2014-01-03
# 49998         Astapor                       2  2014-01-14
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 0                       4.7       1.10     2014-06-17   iPhone       15.4
# 2                       4.3       1.00     2014-01-07   iPhone        0.0
# ...

# %%
### finding users who were retained - adding 6 months to start date then checking if last trip date is in a 30 day range of that number

retainedusers = []
for i in range(len(challenge)):
    start = pd.Timestamp(challenge['signup_date'][i]) #get start date
    end = start + pd.Timedelta('180D') #6 months later
    thirtydayrange = end - pd.Timedelta('30D') #set point 30 days prior
    if thirtydayrange <= pd.Timestamp(challenge['last_trip_date'][i]) <= end:
        retainedusers.append([1]) # now that the active condition has been met, set active user to 1
    else:
        retainedusers.append([0])

# %%
retaineddf = pd.DataFrame(retainedusers, columns=['retainedusers'])

retaineddf.value_counts()




joined = challenge.merge(retaineddf, how='left', left_index=True, right_index=True)

display(joined.head(20))
# Out:
#               city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0   King's Landing                       4  2014-01-25                   4.7
# 1          Astapor                       0  2014-01-29                   5.0
# 2          Astapor                       3  2014-01-06                   4.3
# 3   King's Landing                       9  2014-01-10                   4.6
# 4       Winterfell                      14  2014-01-27                   4.4
# 5       Winterfell                       2  2014-01-09                   3.5
# 6          Astapor                       1  2014-01-24                   NaN
# 7       Winterfell                       2  2014-01-28                   5.0
# 8       Winterfell                       2  2014-01-21                   4.5
# 9       Winterfell                       1  2014-01-03                   NaN
# 10      Winterfell                       1  2014-01-13                   5.0
# ...

# %%
' Roughly ' + str((12701/50000) * 100) + '% of Users who signed up in January were retained'

### roughly 25% retained
# Out:
# ' Roughly 25.402% of Users who signed up in January were retained'

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,15))
print('Correlation between various features')
p=sns.heatmap(joined.corr(), annot=True,cmap ='Blues')
# Out:
# Correlation between various features

# %%
### 1. Fraction of users retained
### 25 % Retained
### from correlation it looks like Distance is slightly negatively correlated with whether a user or not will take another trip in the preceeding 30 days
### Which makes sense, and ultimate black users are slightly postiviely correlated with having a higher chance of taking a trip in the preceding 30 days
joined['monthsactive'] = ((joined.last_trip_date - joined.signup_date)/np.timedelta64(1, 'M'))
display(joined.sort_values(by='last_trip_date', ascending=False).head(10))
# Out:
#                  city  trips_in_first_30_days signup_date  \
# 4486       Winterfell                       4  2014-01-25
# 43047  King's Landing                       1  2014-01-15
# 24059         Astapor                       1  2014-01-24
# 40290  King's Landing                       2  2014-01-07
# 28689  King's Landing                       5  2014-01-16
# 41544      Winterfell                       7  2014-01-22
# 44457      Winterfell                       9  2014-01-13
# 21699      Winterfell                       4  2014-01-13
# 15631  King's Landing                       0  2014-01-15
# 33653      Winterfell                       1  2014-01-07
#
#        avg_rating_of_driver  avg_surge last_trip_date    phone  surge_pct  \
# 4486                    5.0       1.00     2014-07-01  Android        0.0
# 43047                   5.0       1.01     2014-07-01   iPhone        0.8
# 24059                   4.3       1.11     2014-07-01   iPhone       14.3
# ...

# %%
retainedbycity = joined.groupby(['city'])['retainedusers'].sum().sort_values()

ax = retainedbycity.plot(kind='barh', figsize=(4, 4), color='#86bf91', zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("City", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("Total Retained Users", labelpad=20, weight='bold', size=12)

# Set title
ax.set_title("Total Retained Users by City", weight='bold', size=12)
# Out:
# Text(0.5, 1.0, 'Total Retained Users by City')

# %%
retainedbyphone = joined.groupby(['phone'])['retainedusers'].sum().sort_values()

ax = retainedbyphone.plot(kind='barh', figsize=(4, 4), color='#86bf91', zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("Phone Type", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("Total Retained Users", labelpad=20, weight='bold', size=12)

# Set title
ax.set_title("Total Retained Users by Phone", weight='bold', size=12)
# Out:
# Text(0.5, 1.0, 'Total Retained Users by Phone')

# %%
### % of total users with iphone vs % of users with android to verify above results

len(joined[joined['phone'] == 'iPhone']) / (len(joined[joined['phone'] == 'iPhone']) + len(joined[joined['phone'] == 'Android']))
# Out:
# 0.69716151923232

# %%
## % of total users who are ultimate black users

len(joined[joined['ultimate_black_user'] == True]) / 50000
# Out:
# 0.37708

# %%
### group by retained, ultimate black user

# %%
retainedbyultimate = joined.groupby(['ultimate_black_user'])['retainedusers'].sum().sort_values()

ax = retainedbyultimate.plot(kind='barh', figsize=(4, 4), color='#86bf91', zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("# of Retained Users", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("True vs Not True", labelpad=20, weight='bold', size=12)

# Set title
ax.set_title("Total Retained by Ultimate Black Status", weight='bold', size=12)
# Out:
# Text(0.5, 1.0, 'Total Retained by Ultimate Black Status')

# %%
multigroup = joined.groupby(['ultimate_black_user', 'phone', 'city'])['retainedusers'].sum().sort_values(ascending=False)

display(multigroup)
# Out:
# ultimate_black_user  phone    city
# False                iPhone   Winterfell        2400
# True                 iPhone   Winterfell        2288
#                               King's Landing    1778
# False                iPhone   King's Landing    1713
# True                 iPhone   Astapor           1424
# False                iPhone   Astapor            991
#                      Android  Winterfell         522
# True                 Android  Winterfell         414
#                               King's Landing     354
# False                Android  King's Landing     340
# True                 Android  Astapor            201
# False                Android  Astapor            191
# Name: retainedusers, dtype: int64

# %%
multigroup1 = joined.groupby(['phone', 'ultimate_black_user', 'city'])['retainedusers'].sum().sort_values(ascending=False)

display(multigroup1)
# Out:
# phone    ultimate_black_user  city
# iPhone   False                Winterfell        2400
#          True                 Winterfell        2288
#                               King's Landing    1778
#          False                King's Landing    1713
#          True                 Astapor           1424
#          False                Astapor            991
# Android  False                Winterfell         522
#          True                 Winterfell         414
#                               King's Landing     354
#          False                King's Landing     340
#          True                 Astapor            201
#          False                Astapor            191
# Name: retainedusers, dtype: int64

# %% [markdown]
# ### Part 3b - Predictive Modeling

# %%
display(joined.head(5)) ## checking data
# Out:
#              city  trips_in_first_30_days signup_date  avg_rating_of_driver  \
# 0  King's Landing                       4  2014-01-25                   4.7
# 1         Astapor                       0  2014-01-29                   5.0
# 2         Astapor                       3  2014-01-06                   4.3
# 3  King's Landing                       9  2014-01-10                   4.6
# 4      Winterfell                      14  2014-01-27                   4.4
#
#    avg_surge last_trip_date    phone  surge_pct  ultimate_black_user  \
# 0       1.10     2014-06-17   iPhone       15.4                 True
# 1       1.00     2014-05-05  Android        0.0                False
# 2       1.00     2014-01-07   iPhone        0.0                False
# 3       1.14     2014-06-29   iPhone       20.0                 True
# 4       1.19     2014-03-15  Android       11.8                False
#
#    weekday_pct  avg_dist  avg_rating_by_driver  retainedusers  monthsactive
# ...

# %%
### Transform categorical to numerical
joined = pd.get_dummies(joined, columns=['phone', 'city', 'ultimate_black_user'])

display(joined)

##drop missing values

joined = joined.dropna(axis=0)
# Out:
#        trips_in_first_30_days signup_date  avg_rating_of_driver  avg_surge  \
# 0                           4  2014-01-25                   4.7       1.10
# 1                           0  2014-01-29                   5.0       1.00
# 2                           3  2014-01-06                   4.3       1.00
# 3                           9  2014-01-10                   4.6       1.14
# 4                          14  2014-01-27                   4.4       1.19
# ...                       ...         ...                   ...        ...
# 49995                       0  2014-01-25                   5.0       1.00
# 49996                       1  2014-01-24                   NaN       1.00
# 49997                       0  2014-01-31                   5.0       1.00
# 49998                       2  2014-01-14                   3.0       1.00
# 49999                       0  2014-01-18                   NaN       1.00
#
# ...

# %%
y = joined['retainedusers']
X = joined.drop(columns=['retainedusers', 'monthsactive', 'signup_date', 'avg_rating_of_driver', 'last_trip_date', 'surge_pct', 'avg_surge', 'weekday_pct'],
               axis = 1) 

display(X)
# Out:
#        trips_in_first_30_days  avg_dist  avg_rating_by_driver  phone_Android  \
# 0                           4      3.67                   5.0              0
# 1                           0      8.26                   5.0              1
# 2                           3      0.77                   5.0              0
# 3                           9      2.36                   4.9              0
# 4                          14      3.13                   4.9              1
# ...                       ...       ...                   ...            ...
# 49993                       3      2.53                   4.7              0
# 49994                       1      2.25                   4.5              0
# 49995                       0      5.63                   4.2              0
# 49997                       0      3.86                   5.0              1
# 49998                       2      4.58                   3.5              0
#
# ...

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
scaler.transform(X_test)
# Out:
# array([[-0.64667163, -0.66340017,  0.55247443, ..., -0.92581029,
#          0.79071451, -0.79071451],
#        [-0.64667163, -0.67109219, -0.43694104, ...,  1.08013489,
#          0.79071451, -0.79071451],
#        [ 0.10112188, -0.73070532, -0.18958717, ..., -0.92581029,
#          0.79071451, -0.79071451],
#        ...,
#        [-0.64667163, -0.7710884 ,  0.55247443, ...,  1.08013489,
#         -1.26467896,  1.26467896],
#        [ 0.10112188, -0.15188107,  0.30512056, ...,  1.08013489,
#          0.79071451, -0.79071451],
#        [-0.39740713, -0.04996185,  0.55247443, ...,  1.08013489,
#         -1.26467896,  1.26467896]])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix, classification_report

# %%
# Split the data into a training and test set.


clf = LogisticRegression()
# Fit the model on the trainng data.
clf.fit(X_train, y_train)
# Print the accuracy from the testing data.
print(accuracy_score(clf.predict(X_test), y_test))
# Out:
# 0.7356275950175662

# %%
# Predict the labels of the test set: y_pred
y_pred = clf.predict(X_test)

# Compute and print the confusion matrix and classification report
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[8408  533]
#  [2778  805]]
#               precision    recall  f1-score   support
#
#            0       0.75      0.94      0.84      8941
#            1       0.60      0.22      0.33      3583
#
#     accuracy                           0.74     12524
#    macro avg       0.68      0.58      0.58     12524
# weighted avg       0.71      0.74      0.69     12524

# %%
from sklearn.metrics import roc_curve

y_pred_prob = clf.predict_proba(X_test)[:,1]

# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ### Random Forest

# %%
#scale data
from sklearn import preprocessing

# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train)
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)
lr_probs = y_pred_prob[:,1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# Random Forest: Accuracy=0.703
# Random Forest: f1-score=0.700

# %%
### Plotting Feature Importance

feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 10

# %% [markdown]
# ### Final Thoughts

# %% [markdown]
# Since such heavy weight is placed on avg. distance in feature importance, and the definition of "retained" user being quite restrictive, a binary classification method using logistic regression was still able to produce 74% accurate predictions, heavily favoured towards predicting unretained users(83% vs 33% accurate unretained vs. retained.)  I believe if we had more features to experiment with such as demographic data, and had more control over what is deemed a "retained user," that it would be a fun challenge to try and improve the models.
