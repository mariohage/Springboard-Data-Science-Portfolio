# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        SELECT *
        FROM FACILITIES
        """
    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (0, 'Tennis Court 1', 5, 25, 10000, 200)
# (1, 'Tennis Court 2', 5, 25, 8000, 200)
# (2, 'Badminton Court', 0, 15.5, 4000, 50)
# (3, 'Table Tennis', 0, 5, 320, 10)
# (4, 'Massage Room 1', 9.9, 80, 4000, 3000)
# (5, 'Massage Room 2', 9.9, 80, 4000, 3000)
# (6, 'Squash Court', 3.5, 17.5, 5000, 80)
# (7, 'Snooker Table', 0, 5, 450, 15)
# (8, 'Pool Table', 0, 5, 400, 15)

# %%
### question 10

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        select name, totalrevenue from 
        (
        select f.name, 
        sum(case when memid = 0 then slots * f.guestcost else slots * membercost end) as totalrevenue
        from bookings b
        inner join facilities f 
        on b.facid = f.facid
        group by f.name
        )
        as selected_facilities where totalrevenue <= 1000
        order by totalrevenue
        """

    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Table Tennis', 180)
# ('Snooker Table', 240)
# ('Pool Table', 270)

# %%
### question 11

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
       select m1.firstname, m2.surname
        from Members m1 inner join Members m2 
        on m1.memid = m2.recommendedby
        order by m2.surname, m1.firstname
        """

    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ('Ponder', 'Bader')
# ('Jemima', 'Baker')
# ('Ponder', 'Baker')
# ('Tim', 'Boothe')
# ('Darren', 'Butters')
# ('Timothy', 'Coplin')
# ('Tracy', 'Crumpet')
# ('Janice', 'Dare')
# ('Gerald', 'Genting')
# ('Millicent', 'Hunt')
# ('David', 'Jones')
# ('Janice', 'Jones')
# ('Darren', 'Joplette')
# ('Darren', 'Mackenzie')
# ('Darren', 'Owen')
# ('Jemima', 'Pinker')
# ('Tracy', 'Purview')
# ('Matthew', 'Rumney')
# ('Florence', 'Sarwin')
# ('Darren', 'Smith')
# ('Burton', 'Stibbons')
# ('Tracy', 'Worthington-Smyth')

# %%
### question 12

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        select memid, (memid * slots) as usagebymem
        from facilities f INNER JOIN bookings b
        ON f.facid = b.facid
        where b.memid >= 1
        group by b.memid
        """

    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# (1, 2)
# (2, 6)
# (3, 6)
# (4, 8)
# (5, 15)
# (6, 18)
# (7, 21)
# (8, 24)
# (9, 27)
# (10, 30)
# (11, 33)
# (12, 36)
# (13, 26)
# (14, 28)
# (15, 45)
# (16, 48)
# (17, 34)
# (20, 40)
# (21, 63)
# (22, 44)
# (24, 72)
# (26, 78)
# (27, 54)
# (28, 84)
# (29, 87)
# (30, 90)
# (33, 66)
# (35, 105)
# (36, 108)

# %%
### Question 13

# %%
import sqlite3
from sqlite3 import Error

 
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        print(sqlite3.version)
    except Error as e:
        print(e)
 
    return conn

 
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    
    query1 = """
        select MONTH( starttime ), (memid * slots) as usagebymem
        from facilities f INNER JOIN bookings b
        ON f.facid = b.facid
        where b.memid >= 1
        group by b.memid
        """

    cur.execute(query1)
 
    rows = cur.fetchall()
 
    for row in rows:
        print(row)


def main():
    database = "sqlite_db_pythonsqlite.db"
 
    # create a database connection
    conn = create_connection(database)
    with conn: 
        print("2. Query all tasks")
        select_all_tasks(conn)
 
 
if __name__ == '__main__':
    main()
# Out:
# 2.6.0
# 2. Query all tasks
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-38-48d38ffab08e> in <module>
#      54
#      55 if __name__ == '__main__':
# ---> 56     main()
#
# <ipython-input-38-48d38ffab08e> in main()
#      50     with conn:
#      51         print("2. Query all tasks")
# ---> 52         select_all_tasks(conn)
#      53
#      54
#
# <ipython-input-38-48d38ffab08e> in select_all_tasks(conn)
#      35         """
#      36
# ---> 37     cur.execute(query1)
#      38
#      39     rows = cur.fetchall()
#
# OperationalError: no such function: MONTH
